# %% [markdown]
# # gmKriger: A Kriging-based ground motion intensity measure calculator
# ---
# ## PGAs for the 1989 M6.7 Loma Prieta Earthquake

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import gmKriger

# %% [markdown]
# ### Enter sites' ID, latitude, longitude, and site $V_{s30}$

# %%
site = ['Alameda Naval Air Station', 'Treasure Island', 'Alameda Bay Farm Island', 'Farris Farm', 'POO7']
lat  = [37.785748,37.8261394,37.73380567,36.91026828,37.805242]
lon  = [-122.309346,-122.3712351,-122.250101,-121.7437891,-122.339702]
Vs30 = [186.2,181.1,230.7,209.5,223]

# %% [markdown]
# ### Select an earthquake and ground motion intensity measures (GMIMs)

# %%
earthquake = '1989 M6.9 Loma Prieta'
gmims = ['PGA','PGV','Ia','CAV']

# %% [markdown]
# ### Select the correlation model type

# %% [markdown]
# ***realizations***: Select this to use 1000 Bayesian spatial correlation models.<br>
# ***MAP***: Select this to use the ***M***aximum ***A*** ***P***osteriori spatial correlation model.<br>

# %%
model = 'realizations'

# %% [markdown]
# ### Compute ground motions

# %%
dfs = []
for gmim in gmims:
    dfs.append(gmKriger.get_Kgmim(site,lat,lon,Vs30,earthquake,model,gmim))

# %% [markdown]
# ### Results

# %%
results = pd.merge(dfs[0], dfs[1], on=['Site','Lat (deg)','Lon (deg)'], how='outer')
for df in dfs[2:]:
    results = pd.merge(results, df, on=['Site','Lat (deg)','Lon (deg)'], how='outer')
results.T.round(3)
# Out:
#                                       0                          1  \
# Site            Alameda Bay Farm Island  Alameda Naval Air Station
# Lat (deg)                     37.733806                  37.785748
# Lon (deg)                   -122.250101                -122.309346
# PGA (g)                        0.148414                   0.200704
# sigma_PGA (ln)                 0.401558                   0.298392
# PGV (cm/s)                    21.484201                  29.730938
# sigma_PGV (ln)                 0.428639                   0.363152
# Ia (m/s)                       0.253464                   0.343588
# sigma_Ia (ln)                  0.671151                   0.611234
# CAV (m/s)                      4.827996                   5.426928
# sigma_CAV (ln)                 0.301604                   0.276925
#
#                           2           3                4
# Site            Farris Farm        POO7  Treasure Island
# Lat (deg)         36.910268   37.805242        37.826139
# Lon (deg)       -121.743789 -122.339702      -122.371235
# PGA (g)            0.346613    0.149183         0.130778
# sigma_PGA (ln)     0.354027    0.328848         0.255726
# PGV (cm/s)        50.512087   25.237636        24.426841
# sigma_PGV (ln)     0.421651    0.382473         0.333902
# Ia (m/s)           1.762359    0.218926         0.182981
# sigma_Ia (ln)       0.60104    0.561306         0.601669
# CAV (m/s)         10.811714    4.360551         4.357553
# sigma_CAV (ln)     0.277925    0.259685         0.275775
